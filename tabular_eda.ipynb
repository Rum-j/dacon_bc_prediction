# %% [markdown]
# # DACON - 유방암 전이 예측 이진 분류 EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2

# %%
#Load data
pd.set_option('display.max_columns', None)

train_df = pd.read_csv("train.csv") # 1000, 28
test_df = pd.read_csv("test.csv") # 250, 28

print('train df shape:',train_df.shape)
print('test df shape:',test_df.shape)
train_df.head()
# Out:
# train df shape: (1000, 28)
# test df shape: (250, 26)
#            ID                     img_path mask_path  나이       수술연월일  진단명  \
# 0  BC_01_0001  ./train_imgs/BC_01_0001.png         -  63  2015-10-23    1
# 1  BC_01_0002  ./train_imgs/BC_01_0002.png         -  51  2015-10-28    1
# 2  BC_01_0003  ./train_imgs/BC_01_0003.png         -  37  2015-10-29    1
# 3  BC_01_0004  ./train_imgs/BC_01_0004.png         -  54  2016-03-08    1
# 4  BC_01_0005  ./train_imgs/BC_01_0005.png         -  57  2015-10-30    1
#
#    암의 위치  암의 개수  암의 장경   NG   HG  HG_score_1  HG_score_2  HG_score_3  \
# 0      2      1   19.0  2.0  1.0         2.0         2.0         1.0
# 1      1      1   22.0  3.0  3.0         3.0         3.0         3.0
# 2      2      1    NaN  2.0  NaN         NaN         NaN         NaN
# 3      2      1    0.0  3.0  3.0         3.0         3.0         2.0
# 4      2      1    8.0  2.0  2.0         3.0         2.0         1.0
#
#    DCIS_or_LCIS_여부  DCIS_or_LCIS_type  T_category   ER  ER_Allred_score   PR  \
# 0                2                NaN         1.0  1.0              8.0  1.0
# 1                0                NaN         2.0  0.0              NaN  0.0
# 2                1                2.0         0.0  1.0              7.0  1.0
# 3                1                2.0         0.0  0.0              NaN  0.0
# 4                2                NaN         1.0  1.0              8.0  0.0
#
#    PR_Allred_score  KI-67_LI_percent  HER2  HER2_IHC  HER2_SISH  \
# 0              6.0              12.0   0.0       1.0        NaN
# 1              NaN              70.0   0.0       0.0        NaN
# 2              4.0               7.0   0.0       1.0        NaN
# 3              NaN               1.0   1.0       3.0        NaN
# 4              NaN               8.0   1.0       2.0        1.0
#
#    HER2_SISH_ratio  BRCA_mutation  N_category
# 0              NaN            NaN           0
# 1              NaN            NaN           1
# 2              NaN            0.0           0
# 3              NaN            NaN           0
# 4             5.44            NaN           0

# %%
# encoding to ENG

train_df.rename(columns = {'나이':'age',
                           '수술연월일':'yr_mn_dt',
                           '진단명':'diag_cat',
                           '암의 위치':'location',
                           '암의 개수':'sng_mul',
                           '암의 장경':'size_mm',
                           'DCIS_or_LCIS_여부':'DCIS_or_LCIS'},inplace=True)

# %%
import os
os.getcwd()
# Out:
# '/Users/krc/Documents/breast_dacon/open'

# %%
# mask 가 있는 사진 리스트 
have_mask = train_df[train_df['mask_path'] != '-' ]

mask_list = have_mask.mask_path.values.tolist()
have_mask
# Out:
#              ID                     img_path                     mask_path  \
# 13   BC_01_0015  ./train_imgs/BC_01_0015.png  ./train_masks/BC_01_0015.png
# 80   BC_01_0397  ./train_imgs/BC_01_0397.png  ./train_masks/BC_01_0397.png
# 81   BC_01_0398  ./train_imgs/BC_01_0398.png  ./train_masks/BC_01_0398.png
# 82   BC_01_0404  ./train_imgs/BC_01_0404.png  ./train_masks/BC_01_0404.png
# 84   BC_01_0417  ./train_imgs/BC_01_0417.png  ./train_masks/BC_01_0417.png
# 86   BC_01_0425  ./train_imgs/BC_01_0425.png  ./train_masks/BC_01_0425.png
# 88   BC_01_0451  ./train_imgs/BC_01_0451.png  ./train_masks/BC_01_0451.png
# 89   BC_01_0454  ./train_imgs/BC_01_0454.png  ./train_masks/BC_01_0454.png
# 90   BC_01_0455  ./train_imgs/BC_01_0455.png  ./train_masks/BC_01_0455.png
# 91   BC_01_0457  ./train_imgs/BC_01_0457.png  ./train_masks/BC_01_0457.png
# 92   BC_01_0459  ./train_imgs/BC_01_0459.png  ./train_masks/BC_01_0459.png
# 93   BC_01_0471  ./train_imgs/BC_01_0471.png  ./train_masks/BC_01_0471.png
# 100  BC_01_0510  ./train_imgs/BC_01_0510.png  ./train_masks/BC_01_0510.png
# 103  BC_01_0515  ./train_imgs/BC_01_0515.png  ./train_masks/BC_01_0515.png
# 104  BC_01_0516  ./train_imgs/BC_01_0516.png  ./train_masks/BC_01_0516.png
# 106  BC_01_0530  ./train_imgs/BC_01_0530.png  ./train_masks/BC_01_0530.png
# 107  BC_01_0531  ./train_imgs/BC_01_0531.png  ./train_masks/BC_01_0531.png
# 108  BC_01_0532  ./train_imgs/BC_01_0532.png  ./train_masks/BC_01_0532.png
# 111  BC_01_0552  ./train_imgs/BC_01_0552.png  ./train_masks/BC_01_0552.png
# 118  BC_01_0572  ./train_imgs/BC_01_0572.png  ./train_masks/BC_01_0572.png
# 119  BC_01_0583  ./train_imgs/BC_01_0583.png  ./train_masks/BC_01_0583.png
# 120  BC_01_0585  ./train_imgs/BC_01_0585.png  ./train_masks/BC_01_0585.png
# 121  BC_01_0587  ./train_imgs/BC_01_0587.png  ./train_masks/BC_01_0587.png
# 122  BC_01_0591  ./train_imgs/BC_01_0591.png  ./train_masks/BC_01_0591.png
# 124  BC_01_0599  ./train_imgs/BC_01_0599.png  ./train_masks/BC_01_0599.png
# 126  BC_01_0609  ./train_imgs/BC_01_0609.png  ./train_masks/BC_01_0609.png
# 127  BC_01_0612  ./train_imgs/BC_01_0612.png  ./train_masks/BC_01_0612.png
# 133  BC_01_0652  ./train_imgs/BC_01_0652.png  ./train_masks/BC_01_0652.png
# 134  BC_01_0656  ./train_imgs/BC_01_0656.png  ./train_masks/BC_01_0656.png
# 135  BC_01_0660  ./train_imgs/BC_01_0660.png  ./train_masks/BC_01_0660.png
# 136  BC_01_0666  ./train_imgs/BC_01_0666.png  ./train_masks/BC_01_0666.png
# 137  BC_01_0668  ./train_imgs/BC_01_0668.png  ./train_masks/BC_01_0668.png
# 138  BC_01_0673  ./train_imgs/BC_01_0673.png  ./train_masks/BC_01_0673.png
# 139  BC_01_0674  ./train_imgs/BC_01_0674.png  ./train_masks/BC_01_0674.png
# 141  BC_01_0681  ./train_imgs/BC_01_0681.png  ./train_masks/BC_01_0681.png
# 144  BC_01_0693  ./train_imgs/BC_01_0693.png  ./train_masks/BC_01_0693.png
# 145  BC_01_0694  ./train_imgs/BC_01_0694.png  ./train_masks/BC_01_0694.png
# 175  BC_01_0876  ./train_imgs/BC_01_0876.png  ./train_masks/BC_01_0876.png
# 176  BC_01_0877  ./train_imgs/BC_01_0877.png  ./train_masks/BC_01_0877.png
# 178  BC_01_0881  ./train_imgs/BC_01_0881.png  ./train_masks/BC_01_0881.png
# 179  BC_01_0883  ./train_imgs/BC_01_0883.png  ./train_masks/BC_01_0883.png
# 180  BC_01_0885  ./train_imgs/BC_01_0885.png  ./train_masks/BC_01_0885.png
# 181  BC_01_0886  ./train_imgs/BC_01_0886.png  ./train_masks/BC_01_0886.png
# 183  BC_01_0893  ./train_imgs/BC_01_0893.png  ./train_masks/BC_01_0893.png
# 185  BC_01_0902  ./train_imgs/BC_01_0902.png  ./train_masks/BC_01_0902.png
# 186  BC_01_0905  ./train_imgs/BC_01_0905.png  ./train_masks/BC_01_0905.png
# 187  BC_01_0906  ./train_imgs/BC_01_0906.png  ./train_masks/BC_01_0906.png
# 188  BC_01_0907  ./train_imgs/BC_01_0907.png  ./train_masks/BC_01_0907.png
# 189  BC_01_0912  ./train_imgs/BC_01_0912.png  ./train_masks/BC_01_0912.png
# 190  BC_01_0922  ./train_imgs/BC_01_0922.png  ./train_masks/BC_01_0922.png
# 192  BC_01_0925  ./train_imgs/BC_01_0925.png  ./train_masks/BC_01_0925.png
# 193  BC_01_0928  ./train_imgs/BC_01_0928.png  ./train_masks/BC_01_0928.png
# 194  BC_01_0936  ./train_imgs/BC_01_0936.png  ./train_masks/BC_01_0936.png
# 195  BC_01_0938  ./train_imgs/BC_01_0938.png  ./train_masks/BC_01_0938.png
# 198  BC_01_0947  ./train_imgs/BC_01_0947.png  ./train_masks/BC_01_0947.png
# 202  BC_01_0974  ./train_imgs/BC_01_0974.png  ./train_masks/BC_01_0974.png
# 203  BC_01_0980  ./train_imgs/BC_01_0980.png  ./train_masks/BC_01_0980.png
# 204  BC_01_0981  ./train_imgs/BC_01_0981.png  ./train_masks/BC_01_0981.png
#
#      age    yr_mn_dt  diag_cat  location  sng_mul  size_mm   NG   HG  \
# 13    43  2019-02-11         4         1        2     13.0  2.0  1.0
# 80    60  2020-01-08         1         2        1     23.0  2.0  2.0
# 81    58  2019-12-12         1         2        1     13.0  2.0  2.0
# 82    72  2019-12-26         1         2        1     13.0  2.0  1.0
# 84    51  2019-12-05         1         2        2     21.0  2.0  2.0
# 86    46  2019-12-12         4         1        1      5.0  1.0  1.0
# 88    33  2019-11-05         1         2        2     22.0  3.0  3.0
# 89    62  2019-10-22         1         1        1     13.0  2.0  2.0
# 90    46  2019-10-07         1         2        1     14.0  2.0  2.0
# 91    44  2019-10-30         2         2        2     40.0  2.0  2.0
# 92    48  2019-10-11         1         2        1     24.0  2.0  2.0
# 93    48  2019-09-25         4         1        1     14.0  1.0  1.0
# 100   50  2019-03-04         4         2        1     10.0  1.0  1.0
# 103   59  2019-01-18         1         1        1     17.0  3.0  3.0
# 104   89  2019-02-13         1         1        1     71.0  3.0  3.0
# 106   54  2019-01-22         1         2        1     15.0  3.0  3.0
# 107   56  2019-01-23         2         2        1     16.0  2.0  2.0
# 108   80  2019-01-16         1         1        1     15.0  2.0  2.0
# 111   47  2019-01-15         1         1        2      8.0  2.0  2.0
# 118   45  2018-08-03         2         2        1      6.0  1.0  1.0
# 119   58  2018-08-21         1         2        2     21.0  2.0  2.0
# 120   72  2018-08-24         1         2        1     20.0  3.0  2.0
# 121   41  2018-08-24         3         1        1     24.0  1.0  1.0
# 122   40  2018-08-30         3         1        1     14.0  1.0  1.0
# 124   57  2018-07-30         1         1        1     17.0  2.0  2.0
# 126   41  2018-08-27         2         1        2     32.0  2.0  2.0
# 127   48  2018-07-09         1         1        1     45.0  3.0  2.0
# 133   56  2018-06-22         1         2        1     20.0  2.0  2.0
# 134   58  2018-07-12         1         1        2     12.0  2.0  2.0
# 135   62  2018-07-09         1         1        1     22.0  2.0  2.0
# 136   81  2018-07-05         1         1        1     11.0  2.0  1.0
# 137   65  2018-06-15         1         2        2     29.0  3.0  2.0
# 138   61  2018-05-16         1         1        1     21.0  2.0  2.0
# 139   60  2018-05-15         1         1        2      4.0  2.0  2.0
# 141   45  2018-06-14         1         1        1     21.0  3.0  3.0
# 144   39  2018-04-23         1         1        1     16.0  2.0  1.0
# 145   67  2018-05-25         1         1        2     11.0  2.0  2.0
# 175   60  2017-10-19         1         1        2     14.0  3.0  3.0
# 176   61  2017-10-19         1         1        1      5.0  2.0  1.0
# 178   43  2017-11-01         1         2        1     13.0  3.0  2.0
# 179   48  2017-10-27         1         1        1     28.0  3.0  3.0
# 180   41  2017-11-07         1         2        1     21.0  3.0  2.0
# 181   36  2017-10-12         4         1        1     21.0  2.0  2.0
# 183   70  2017-10-13         1         2        1     19.0  3.0  3.0
# 185   65  2017-09-21         1         2        2     27.0  2.0  2.0
# 186   68  2017-09-27         1         1        1     17.0  2.0  2.0
# 187   46  2017-09-15         2         1        1     34.0  2.0  2.0
# 188   65  2017-09-21         1         2        1     25.0  2.0  2.0
# 189   57  2017-09-14         1         2        2     18.0  3.0  3.0
# 190   45  2017-08-29         1         2        2     13.0  2.0  2.0
# 192   48  2017-08-17         1         2        2     22.0  2.0  2.0
# 193   48  2017-08-10         2         1        2     22.0  1.0  1.0
# 194   54  2017-08-04         2         1        1     23.0  1.0  1.0
# 195   60  2017-08-11         3         2        1     16.0  1.0  1.0
# 198   43  2017-08-11         1         1        1     16.0  2.0  1.0
# 202   53  2017-07-06         2         2        2     16.0  2.0  2.0
# 203   52  2017-06-27         1         2        1     18.0  3.0  3.0
# 204   59  2017-06-19         1         1        1     16.0  3.0  3.0
#
#      HG_score_1  HG_score_2  HG_score_3  DCIS_or_LCIS  DCIS_or_LCIS_type  \
# 13          2.0         2.0         1.0             2                NaN
# 80          3.0         2.0         2.0             0                NaN
# 81          3.0         2.0         1.0             0                NaN
# 82          2.0         2.0         1.0             2                NaN
# 84          3.0         2.0         1.0             2                NaN
# 86          1.0         1.0         1.0             0                NaN
# 88          3.0         3.0         2.0             2                NaN
# 89          2.0         2.0         2.0             2                NaN
# 90          3.0         2.0         1.0             2                NaN
# 91          3.0         2.0         1.0             2                NaN
# 92          3.0         2.0         2.0             2                NaN
# 93          1.0         1.0         1.0             2                NaN
# 100         1.0         1.0         1.0             0                NaN
# 103         3.0         3.0         2.0             2                NaN
# 104         3.0         3.0         3.0             2                NaN
# 106         3.0         3.0         2.0             2                NaN
# 107         3.0         2.0         1.0             2                NaN
# 108         3.0         2.0         1.0             2                NaN
# 111         3.0         2.0         1.0             0                NaN
# 118         1.0         1.0         1.0             2                NaN
# 119         3.0         2.0         2.0             0                NaN
# 120         3.0         3.0         1.0             2                NaN
# 121         2.0         1.0         1.0             0                NaN
# 122         2.0         1.0         1.0             0                NaN
# 124         3.0         2.0         1.0             2                NaN
# 126         3.0         2.0         1.0             2                NaN
# 127         3.0         3.0         1.0             2                NaN
# 133         2.0         2.0         2.0             2                NaN
# 134         3.0         2.0         1.0             2                NaN
# 135         3.0         2.0         1.0             2                NaN
# 136         2.0         2.0         1.0             2                NaN
# 137         3.0         3.0         1.0             2                NaN
# 138         3.0         2.0         1.0             2                NaN
# 139         3.0         2.0         1.0             2                NaN
# 141         3.0         3.0         3.0             2                NaN
# 144         2.0         2.0         1.0             2                NaN
# 145         3.0         2.0         1.0             0                NaN
# 175         3.0         3.0         2.0             2                NaN
# 176         2.0         2.0         1.0             0                NaN
# 178         3.0         3.0         1.0             2                NaN
# 179         3.0         3.0         3.0             2                NaN
# 180         3.0         3.0         1.0             2                NaN
# 181         3.0         2.0         2.0             2                NaN
# 183         3.0         3.0         3.0             2                NaN
# 185         3.0         2.0         1.0             2                NaN
# 186         3.0         2.0         1.0             2                NaN
# 187         3.0         2.0         1.0             0                NaN
# 188         3.0         2.0         1.0             2                NaN
# 189         3.0         3.0         3.0             2                NaN
# 190         3.0         2.0         1.0             2                NaN
# 192         3.0         2.0         1.0             2                NaN
# 193         3.0         1.0         1.0             2                NaN
# 194         3.0         1.0         1.0             2                NaN
# 195         2.0         1.0         1.0             0                NaN
# 198         2.0         2.0         1.0             2                NaN
# 202         3.0         2.0         1.0             2                NaN
# 203         3.0         3.0         3.0             2                NaN
# 204         3.0         3.0         3.0             2                NaN
#
#      T_category   ER  ER_Allred_score   PR  PR_Allred_score  KI-67_LI_percent  \
# 13          1.0  1.0              7.0  1.0              8.0             10.01
# 80          2.0  1.0              7.0  1.0              6.0             20.22
# 81          1.0  1.0              8.0  1.0              5.0             20.93
# 82          1.0  1.0              7.0  1.0              8.0              6.38
# 84          2.0  1.0              7.0  0.0              NaN             18.86
# 86          1.0  1.0              6.0  1.0              6.0              4.60
# 88          2.0  1.0              6.0  1.0              4.0             44.92
# 89          1.0  1.0              7.0  1.0              6.0             11.84
# 90          1.0  1.0              7.0  1.0              8.0             16.37
# 91          2.0  1.0              7.0  1.0              6.0              2.60
# 92          2.0  1.0              6.0  1.0              6.0             26.84
# 93          1.0  1.0              6.0  1.0              7.0              8.41
# 100         1.0  1.0              7.0  1.0              8.0              9.32
# 103         1.0  1.0              8.0  0.0              NaN             21.53
# 104         4.0  1.0              8.0  0.0              NaN             50.82
# 106         1.0  1.0              7.0  1.0              7.0             24.15
# 107         1.0  1.0              7.0  1.0              7.0             17.00
# 108         1.0  1.0              7.0  0.0              NaN             36.40
# 111         1.0  1.0              8.0  1.0              8.0             15.51
# 118         1.0  1.0              6.0  1.0              8.0              5.38
# 119         2.0  1.0              3.0  0.0              NaN             57.65
# 120         1.0  1.0              8.0  1.0              7.0             19.95
# 121         2.0  1.0              6.0  1.0              6.0             28.97
# 122         1.0  1.0              7.0  1.0              6.0             10.39
# 124         1.0  1.0              7.0  1.0              5.0             34.19
# 126         2.0  1.0              7.0  1.0              7.0             12.06
# 127         2.0  1.0              7.0  1.0              8.0             23.80
# 133         1.0  1.0              8.0  0.0              NaN             23.96
# 134         1.0  1.0              8.0  1.0              4.0              5.64
# 135         2.0  1.0              8.0  1.0              8.0             11.14
# 136         1.0  1.0              8.0  1.0              4.0             23.21
# 137         2.0  1.0              8.0  0.0              NaN             13.27
# 138         2.0  1.0              8.0  1.0              5.0              0.91
# 139         1.0  1.0              7.0  0.0              NaN              8.63
# 141         2.0  1.0              6.0  1.0              6.0             43.08
# 144         1.0  1.0              7.0  1.0              6.0             20.27
# 145         1.0  1.0              8.0  1.0              6.0             17.27
# 175         1.0  0.0              NaN  0.0              NaN             77.22
# 176         1.0  1.0              8.0  1.0              8.0              5.53
# 178         1.0  1.0              8.0  1.0              8.0             17.94
# 179         2.0  0.0              NaN  0.0              NaN             44.02
# 180         2.0  1.0              8.0  1.0              8.0             11.02
# 181         2.0  1.0              3.0  1.0              4.0             60.12
# 183         1.0  0.0              NaN  0.0              NaN             17.32
# 185         2.0  1.0              8.0  1.0              4.0              4.46
# 186         1.0  1.0              8.0  1.0              4.0             10.05
# 187         2.0  1.0              7.0  1.0              5.0             14.63
# 188         2.0  0.0              NaN  0.0              NaN             45.55
# 189         1.0  1.0              5.0  0.0              NaN             27.57
# 190         1.0  1.0              8.0  1.0              8.0             19.33
# 192         2.0  1.0              6.0  1.0              8.0             13.58
# 193         2.0  1.0              7.0  1.0              4.0              3.85
# 194         2.0  1.0              7.0  1.0              3.0              9.68
# 195         1.0  1.0              8.0  1.0              4.0             23.80
# 198         1.0  1.0              7.0  1.0              7.0             23.37
# 202         1.0  1.0              8.0  0.0              NaN              3.98
# 203         1.0  1.0              7.0  1.0              7.0             26.09
# 204         1.0  1.0              8.0  0.0              NaN             28.35
#
#      HER2  HER2_IHC  HER2_SISH  HER2_SISH_ratio  BRCA_mutation  N_category
# 13    0.0       2.0        0.0             1.23            NaN           0
# 80    0.0       0.0        NaN              NaN            NaN           1
# 81    0.0       1.0        NaN              NaN            NaN           1
# 82    0.0       1.0        NaN              NaN            NaN           1
# 84    0.0       2.0        0.0             1.27            NaN           1
# 86    0.0       2.0        0.0             1.10            NaN           0
# 88    0.0       2.0        0.0             1.42            NaN           1
# 89    0.0       2.0        0.0             1.32            NaN           1
# 90    0.0       1.0        NaN              NaN            NaN           1
# 91    0.0       1.0        NaN              NaN            NaN           1
# 92    0.0       1.0        NaN              NaN            NaN           1
# 93    0.0       2.0        0.0             1.24            NaN           0
# 100   0.0       1.0        NaN              NaN            NaN           0
# 103   0.0       2.0        0.0             1.19            NaN           1
# 104   1.0       3.0        NaN              NaN            NaN           1
# 106   0.0       2.0        0.0             1.44            NaN           1
# 107   0.0       0.0        NaN              NaN            NaN           1
# 108   0.0       1.0        NaN              NaN            NaN           1
# 111   0.0       1.0        NaN              NaN            NaN           1
# 118   0.0       1.0        NaN              NaN            NaN           0
# 119   1.0       3.0        NaN              NaN            NaN           1
# 120   0.0       1.0        NaN              NaN            NaN           1
# 121   0.0       1.0        NaN              NaN            NaN           0
# 122   0.0       0.0        NaN              NaN            NaN           0
# 124   0.0       2.0        0.0             1.13            NaN           1
# 126   0.0       1.0        NaN              NaN            NaN           1
# 127   0.0       1.0        NaN              NaN            NaN           1
# 133   0.0       1.0        NaN              NaN            NaN           1
# 134   0.0       2.0        0.0             1.04            NaN           1
# 135   0.0       0.0        NaN              NaN            NaN           1
# 136   0.0       2.0        0.0             1.05            NaN           1
# 137   0.0       1.0        NaN              NaN            NaN           1
# 138   0.0       1.0        NaN              NaN            NaN           1
# 139   0.0       2.0        0.0             1.44            NaN           1
# 141   1.0       3.0        NaN              NaN            NaN           1
# 144   0.0       1.0        NaN              NaN            NaN           1
# 145   0.0       0.0        NaN              NaN            NaN           1
# 175   0.0       1.0        NaN              NaN            NaN           1
# 176   0.0       1.0        NaN              NaN            NaN           1
# 178   1.0       3.0        NaN              NaN            NaN           1
# 179   1.0       3.0        NaN              NaN            NaN           1
# 180   0.0       0.0        NaN              NaN            NaN           1
# 181   1.0       3.0        NaN              NaN            NaN           1
# 183   0.0       2.0        0.0             1.36            NaN           1
# 185   0.0       2.0        0.0             1.56            NaN           1
# 186   0.0       1.0        NaN              NaN            NaN           1
# 187   0.0       0.0        NaN              NaN            NaN           1
# 188   0.0       1.0        NaN              NaN            NaN           1
# 189   1.0       3.0        NaN              NaN            NaN           1
# 190   0.0       0.0        NaN              NaN            NaN           1
# 192   0.0       1.0        NaN              NaN            NaN           1
# 193   0.0       2.0        0.0             0.97            NaN           1
# 194   0.0       0.0        NaN              NaN            NaN           1
# 195   0.0       0.0        NaN              NaN            NaN           0
# 198   0.0       1.0        NaN              NaN            NaN           1
# 202   0.0       1.0        NaN              NaN            NaN           1
# 203   0.0       1.0        NaN              NaN            NaN           1
# 204   1.0       3.0        NaN              NaN            NaN           1

# %%
# 중복된 이미지 자르기? 
num_list = ['0007','0010','0062','0178','0214','0215','0217','0230','0246','0268','0284','0285','0298','0302']
image_ls = '|'.join(num_list)
train_df[train_df['img_path'].str.contains(image_ls)]
# Out:
#             ID                     img_path mask_path  나이       수술연월일  진단명  \
# 6   BC_01_0007  ./train_imgs/BC_01_0007.png         -  57  2015-12-18    1
# 9   BC_01_0010  ./train_imgs/BC_01_0010.png         -  46  2015-11-18    1
# 14  BC_01_0062  ./train_imgs/BC_01_0062.png         -  51  2019-10-30    1
# 15  BC_01_0178  ./train_imgs/BC_01_0178.png         -  36  2019-05-27    1
# 18  BC_01_0214  ./train_imgs/BC_01_0214.png         -  58  2020-06-29    1
# 19  BC_01_0215  ./train_imgs/BC_01_0215.png         -  36  2020-06-18    1
# 21  BC_01_0217  ./train_imgs/BC_01_0217.png         -  54  2020-06-30    1
# 28  BC_01_0230  ./train_imgs/BC_01_0230.png         -  48  2020-06-15    1
# 34  BC_01_0246  ./train_imgs/BC_01_0246.png         -  40  2020-05-14    1
# 45  BC_01_0268  ./train_imgs/BC_01_0268.png         -  55  2020-04-10    1
# 51  BC_01_0284  ./train_imgs/BC_01_0284.png         -  43  2020-04-02    1
# 52  BC_01_0285  ./train_imgs/BC_01_0285.png         -  39  2020-04-14    1
# 60  BC_01_0298  ./train_imgs/BC_01_0298.png         -  55  2020-03-11    1
# 63  BC_01_0302  ./train_imgs/BC_01_0302.png         -  78  2020-03-24    1
#
#     암의 위치  암의 개수  암의 장경   NG   HG  HG_score_1  HG_score_2  HG_score_3  \
# 6       1      1    NaN  2.0  NaN         NaN         NaN         NaN
# 9       1      1    NaN  1.0  NaN         NaN         NaN         NaN
# 14      1      1   25.0  3.0  3.0         3.0         3.0         3.0
# 15      2      2    2.0  3.0  2.0         3.0         3.0         1.0
# 18      1      1    NaN  NaN  NaN         NaN         NaN         NaN
# 19      2      2    5.0  2.0  2.0         3.0         2.0         2.0
# 21      1      1   16.0  NaN  NaN         NaN         NaN         NaN
# 28      1      1   10.0  NaN  NaN         NaN         NaN         NaN
# 34      2      2   19.0  2.0  2.0         3.0         2.0         2.0
# 45      2      1    3.0  2.0  2.0         3.0         2.0         1.0
# 51      1      1    NaN  1.0  NaN         NaN         NaN         NaN
# 52      2      1    NaN  2.0  NaN         NaN         NaN         NaN
# 60      2      1   20.0  3.0  3.0         3.0         3.0         3.0
# 63      2      1    NaN  2.0  NaN         NaN         NaN         NaN
#
#     DCIS_or_LCIS_여부  DCIS_or_LCIS_type  T_category   ER  ER_Allred_score   PR  \
# 6                 1                2.0         0.0  1.0              6.0  1.0
# 9                 1                2.0         0.0  1.0              7.0  1.0
# 14                2                2.0         2.0  0.0              NaN  0.0
# 15                2                1.0         1.0  0.0              NaN  0.0
# 18                1                2.0         0.0  0.0              NaN  0.0
# 19                2                2.0         1.0  1.0              6.0  1.0
# 21                1                2.0         1.0  0.0              NaN  0.0
# 28                1                1.0         1.0  1.0              4.0  1.0
# 34                2                2.0         1.0  1.0              7.0  1.0
# 45                2                1.0         1.0  0.0              NaN  0.0
# 51                1                2.0         0.0  1.0              7.0  1.0
# 52                1                2.0         0.0  1.0              7.0  1.0
# 60                2                2.0         1.0  0.0              NaN  0.0
# 63                1                2.0         0.0  1.0              8.0  1.0
#
#     PR_Allred_score  KI-67_LI_percent  HER2  HER2_IHC  HER2_SISH  \
# 6               4.0              5.00   1.0       3.0        NaN
# 9               4.0              7.00   0.0       0.0        NaN
# 14              NaN             50.96   0.0       1.0        NaN
# 15              NaN             89.17   0.0       0.0        NaN
# 18              NaN             28.66   NaN       2.0        0.0
# 19              4.0             20.15   0.0       2.0        0.0
# 21              NaN             17.36   1.0       3.0        NaN
# 28              4.0             14.91   0.0       2.0        NaN
# 34              8.0             15.18   0.0       2.0        0.0
# 45              NaN             10.88   0.0       1.0        NaN
# 51              8.0              7.96   0.0       2.0        NaN
# 52              4.0               NaN   0.0       2.0        0.0
# 60              NaN             34.89   1.0       3.0        NaN
# 63              6.0               NaN   0.0       2.0        0.0
#
#     HER2_SISH_ratio  BRCA_mutation  N_category
# 6               NaN            NaN           0
# 9               NaN            0.0           0
# 14              NaN            0.0           0
# 15              NaN            0.0           0
# 18            30.00            NaN           0
# 19             1.33            0.0           1
# 21              NaN            NaN           0
# 28              NaN            NaN           0
# 34             1.52            0.0           1
# 45              NaN            NaN           0
# 51              NaN            NaN           0
# 52             1.03            2.0           0
# 60              NaN            NaN           0
# 63             1.56            NaN           0

# %%
train_df.info() #Non-null 및 categorical column 구분
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 1000 non-null   object
#  1   img_path           1000 non-null   object
#  2   mask_path          1000 non-null   object
#  3   age                1000 non-null   int64
#  4   yr_mn_dt           1000 non-null   object
#  5   diag_cat           1000 non-null   int64
#  6   location           1000 non-null   int64
#  7   sng_mul            1000 non-null   int64
#  8   size_mm            931 non-null    float64
#  9   NG                 949 non-null    float64
#  10  HG                 914 non-null    float64
#  11  HG_score_1         908 non-null    float64
#  12  HG_score_2         908 non-null    float64
#  13  HG_score_3         911 non-null    float64
#  14  DCIS_or_LCIS       1000 non-null   int64
#  15  DCIS_or_LCIS_type  126 non-null    float64
#  16  T_category         996 non-null    float64
#  17  ER                 999 non-null    float64
#  18  ER_Allred_score    703 non-null    float64
#  19  PR                 999 non-null    float64
#  20  PR_Allred_score    547 non-null    float64
#  21  KI-67_LI_percent   765 non-null    float64
#  22  HER2               986 non-null    float64
#  23  HER2_IHC           976 non-null    float64
#  24  HER2_SISH          247 non-null    float64
#  25  HER2_SISH_ratio    175 non-null    float64
#  26  BRCA_mutation      55 non-null     float64
#  27  N_category         1000 non-null   int64
# dtypes: float64(18), int64(6), object(4)
# memory usage: 218.9+ KB

# %%
train_df[train_df['N_category'] == 1]
# Out:
#              ID                     img_path mask_path  age    yr_mn_dt  \
# 1    BC_01_0002  ./train_imgs/BC_01_0002.png         -   51  2015-10-28
# 19   BC_01_0215  ./train_imgs/BC_01_0215.png         -   36  2020-06-18
# 22   BC_01_0218  ./train_imgs/BC_01_0218.png         -   71  2020-06-26
# 23   BC_01_0223  ./train_imgs/BC_01_0223.png         -   40  2020-06-11
# 26   BC_01_0227  ./train_imgs/BC_01_0227.png         -   50  2020-06-05
# ..          ...                          ...       ...  ...         ...
# 984  BC_01_3336  ./train_imgs/BC_01_3336.png         -   73  2009-10-27
# 989  BC_01_3405  ./train_imgs/BC_01_3405.png         -   61  2009-05-19
# 995  BC_01_3464  ./train_imgs/BC_01_3464.png         -   65  2006-12-22
# 997  BC_01_3485  ./train_imgs/BC_01_3485.png         -   64  2006-11-10
# 999  BC_01_3518  ./train_imgs/BC_01_3518.png         -   76  2010-09-01
#
#      diag_cat  location  sng_mul  size_mm   NG   HG  HG_score_1  HG_score_2  \
# 1           1         1        1     22.0  3.0  3.0         3.0         3.0
# 19          1         2        2      5.0  2.0  2.0         3.0         2.0
# 22          1         2        2      0.1  2.0  2.0         3.0         2.0
# 23          1         2        2      9.0  2.0  2.0         3.0         2.0
# 26          4         1        2     27.0  3.0  3.0         3.0         3.0
# ..        ...       ...      ...      ...  ...  ...         ...         ...
# 984         1         1        1     19.0  2.0  2.0         3.0         2.0
# 989         1         2        1     14.0  1.0  1.0         1.0         1.0
# 995         1         2        1     25.0  1.0  1.0         2.0         1.0
# 997         1         2        1     15.0  1.0  1.0         2.0         1.0
# 999         1         2        1     20.0  3.0  3.0         2.0         3.0
#
#      HG_score_3  DCIS_or_LCIS  DCIS_or_LCIS_type  T_category   ER  \
# 1           3.0             0                NaN         2.0  0.0
# 19          2.0             2                2.0         1.0  1.0
# 22          1.0             2                2.0         2.0  1.0
# 23          1.0             0                1.0         1.0  1.0
# 26          2.0             2                1.0         2.0  1.0
# ..          ...           ...                ...         ...  ...
# 984         1.0             0                NaN         1.0  1.0
# 989         1.0             0                NaN         1.0  1.0
# 995         1.0             0                NaN         2.0  1.0
# 997         2.0             0                NaN         1.0  1.0
# 999         3.0             0                NaN         1.0  1.0
#
#      ER_Allred_score   PR  PR_Allred_score  KI-67_LI_percent  HER2  HER2_IHC  \
# 1                NaN  0.0              NaN             70.00   0.0       0.0
# 19               6.0  1.0              4.0             20.15   0.0       2.0
# 22               7.0  1.0              5.0              3.81   0.0       1.0
# 23               7.0  1.0              7.0             13.40   0.0       1.0
# 26               7.0  1.0              7.0             34.01   0.0       1.0
# ..               ...  ...              ...               ...   ...       ...
# 984              5.0  1.0              5.0             14.00   0.0       0.0
# 989              5.0  1.0              2.0               NaN   0.0       1.0
# 995              NaN  0.0              NaN               NaN   0.0       0.0
# 997              NaN  1.0              NaN               NaN   0.0       0.0
# 999              4.0  0.0              2.0               NaN   0.0       1.0
#
#      HER2_SISH  HER2_SISH_ratio  BRCA_mutation  N_category
# 1          NaN              NaN            NaN           1
# 19         0.0             1.33            0.0           1
# 22         NaN              NaN            NaN           1
# 23         NaN              NaN            NaN           1
# 26         0.0             0.00            NaN           1
# ..         ...              ...            ...         ...
# 984        NaN              NaN            NaN           1
# 989        NaN              NaN            NaN           1
# 995        NaN              NaN            NaN           1
# 997        NaN              NaN            NaN           1
# 999        NaN              NaN            NaN           1
#
# [514 rows x 28 columns]

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 250 non-null    object
#  1   img_path           250 non-null    object
#  2   나이                 250 non-null    int64
#  3   수술연월일              250 non-null    object
#  4   진단명                250 non-null    int64
#  5   암의 위치              250 non-null    int64
#  6   암의 개수              250 non-null    int64
#  7   암의 장경              237 non-null    float64
#  8   NG                 235 non-null    float64
#  9   HG                 234 non-null    float64
#  10  HG_score_1         232 non-null    float64
#  11  HG_score_2         232 non-null    float64
#  12  HG_score_3         232 non-null    float64
#  13  DCIS_or_LCIS_여부    250 non-null    int64
#  14  DCIS_or_LCIS_type  31 non-null     float64
#  15  T_category         249 non-null    float64
#  16  ER                 250 non-null    float64
#  17  ER_Allred_score    175 non-null    float64
#  18  PR                 250 non-null    float64
#  19  PR_Allred_score    133 non-null    float64
#  20  KI-67_LI_percent   198 non-null    float64
#  21  HER2               244 non-null    float64
#  22  HER2_IHC           247 non-null    float64
#  23  HER2_SISH          61 non-null     float64
#  24  HER2_SISH_ratio    45 non-null     float64
#  25  BRCA_mutation      12 non-null     float64
# dtypes: float64(18), int64(5), object(3)
# memory usage: 50.9+ KB

# %%
#numeric columns from baseline
numeric_cols = ['age', 'size_mm', 'ER_Allred_score', 'PR_Allred_score', 'KI-67_LI_percent', 'HER2_SISH_ratio','N_category']

#categorical 
cat_cols = ['diag_cat','location','sng_mul','NG','HG','HG_score_1','HG_score_2','HG_score_3','DCIS_or_LCIS','DCIS_or_LCIS_type','T_category','ER','PR','HER2','HER2_IHC','HER2_SISH','BRCA_mutation','N_category']

# %%
# 분포 관찰

train_df.iloc[:,8:].describe()
# Out:
#           size_mm          NG          HG  HG_score_1  HG_score_2  HG_score_3  \
# count  931.000000  949.000000  914.000000  908.000000  908.000000  911.000000
# mean    18.375564    2.070601    1.897155    2.588106    2.144273    1.428101
# std     12.037144    0.692234    0.713147    0.654011    0.655820    0.714866
# min      0.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%     11.000000    2.000000    1.000000    2.000000    2.000000    1.000000
# 50%     17.000000    2.000000    2.000000    3.000000    2.000000    1.000000
# 75%     23.000000    3.000000    2.000000    3.000000    3.000000    2.000000
# max    110.000000    3.000000    3.000000    3.000000    3.000000    4.000000
#
#        DCIS_or_LCIS  DCIS_or_LCIS_type  T_category         ER  \
# count   1000.000000         126.000000  996.000000  999.00000
# mean       0.719000           1.452381    1.279116    0.81982
# std        0.915903           0.499714    0.632778    0.38453
# min        0.000000           1.000000    0.000000    0.00000
# 25%        0.000000           1.000000    1.000000    1.00000
# 50%        0.000000           1.000000    1.000000    1.00000
# 75%        2.000000           2.000000    2.000000    1.00000
# max        2.000000           2.000000    4.000000    1.00000
#
#        ER_Allred_score          PR  PR_Allred_score  KI-67_LI_percent  \
# count       703.000000  999.000000       547.000000        765.000000
# mean          7.014225    0.641642         6.049360         18.037229
# std           1.125879    0.479758         2.734821         18.846473
# min           3.000000    0.000000         2.000000          0.000000
# 25%           7.000000    0.000000         5.000000          5.000000
# 50%           7.000000    1.000000         6.000000         10.000000
# 75%           8.000000    1.000000         7.000000         25.000000
# max           8.000000    1.000000        54.000000         97.000000
#
#              HER2    HER2_IHC   HER2_SISH  HER2_SISH_ratio  BRCA_mutation  \
# count  986.000000  976.000000  247.000000       175.000000      55.000000
# mean     0.247465    1.253074    0.129555         2.460457       0.145455
# std      0.431758    0.939444    0.336495         7.399121       0.524164
# min      0.000000    0.000000    0.000000         0.000000       0.000000
# 25%      0.000000    0.000000    0.000000         1.130000       0.000000
# 50%      0.000000    1.000000    0.000000         1.270000       0.000000
# 75%      0.000000    2.000000    0.000000         1.675000       0.000000
# max      1.000000    3.000000    1.000000        94.000000       2.000000
#
#         N_category
# count  1000.000000
# mean      0.514000
# std       0.500054
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
train_df.size_mm.value_counts()
# Out:
# 15.0    56
# 22.0    46
# 18.0    45
# 13.0    45
# 21.0    42
#         ..
# 0.1      1
# 81.0     1
# 68.0     1
# 0.7      1
# 57.0     1
# Name: size_mm, Length: 73, dtype: int64

# %%
train_df.T_category.value_counts()
# Out:
# 1.0    600
# 2.0    305
# 0.0     71
# 3.0     16
# 4.0      4
# Name: T_category, dtype: int64

# %% [markdown]
# ## Numeric Column 들 살펴보기
#
# 결측치 채우는 방법 및 채우기 전 VS 후 전이 여부와의 관계 살필 필요가 있음
#
# ### 암의 장경

# %%
num_df = train_df[numeric_cols]

num_df.head()
# Out:
#    age  size_mm  ER_Allred_score  PR_Allred_score  KI-67_LI_percent  \
# 0   63     19.0              8.0              6.0              12.0
# 1   51     22.0              NaN              NaN              70.0
# 2   37      NaN              7.0              4.0               7.0
# 3   54      0.0              NaN              NaN               1.0
# 4   57      8.0              8.0              NaN               8.0
#
#    HER2_SISH_ratio  N_category
# 0              NaN           0
# 1              NaN           1
# 2              NaN           0
# 3              NaN           0
# 4             5.44           0

# %%
# 암의 장경 분포 


size_fig =sns.catplot(x ='size_mm',
            data=num_df, 
            kind='count',
            height =12
           )

size_fig.set_xticklabels(rotation=90)

plt.show()

# %%
# 장경 크기 VS 전이 여부

size_corr = sns.catplot( x="size_mm",
                       data=num_df,
                       hue = 'N_category',
                       kind='count',
                       height =10)

size_corr.set_xticklabels(rotation=90)

plt.show()

# %% [markdown]
# #### 관찰 1
# > 전이된 암의 size의 평균이 전이되지 않은 암보다 다소 높음
#
# > 결측값 : 전이 안된 케이스가 더 많음, 0 으로 채우기?

# %% [markdown]
# ### 'ER_Allred_score'

# %%
#ER_Allred_score : 에스트로겐 수용체 관련 
shape_fig =sns.catplot(x ='ER_Allred_score',
            data=train_df, 
            kind='count',
           # height =8,
            hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %% [markdown]
# ### 'PR_Allred_score'

# %%
#PR_Allred_score : 프로게스테론 수용체 관련 
shape_fig =sns.catplot(x ='PR_Allred_score',
            data=num_df, 
            kind='count',
           # height =8,
           hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %%
train_df[train_df.PR_Allred_score > 9]
# Out:
#             ID                     img_path mask_path  age    yr_mn_dt  \
# 66  BC_01_0308  ./train_imgs/BC_01_0308.png         -   62  2020-03-10
# 67  BC_01_0309  ./train_imgs/BC_01_0309.png         -   77  2020-03-02
#
#     diag_cat  location  sng_mul  size_mm   NG   HG  HG_score_1  HG_score_2  \
# 66         1         1        1     15.0  2.0  2.0         3.0         2.0
# 67         1         2        1     33.0  3.0  3.0         3.0         3.0
#
#     HG_score_3  DCIS_or_LCIS  DCIS_or_LCIS_type  T_category   ER  \
# 66         2.0             2                2.0         1.0  1.0
# 67         3.0             2                2.0         2.0  1.0
#
#     ER_Allred_score   PR  PR_Allred_score  KI-67_LI_percent  HER2  HER2_IHC  \
# 66              7.0  1.0             23.0             24.99   0.0       2.0
# 67              6.0  1.0             54.0             45.27   1.0       3.0
#
#     HER2_SISH  HER2_SISH_ratio  BRCA_mutation  N_category
# 66        0.0             1.31            0.0           1
# 67        NaN              NaN            NaN           0

# %% [markdown]
# #### 전처리 항목
# > 22, 54는 outlier

# %% [markdown]
# ### KI-67_LI_percent

# %%
num_df['KI-67_LI_percent']
# Out:
# 0      12.0
# 1      70.0
# 2       7.0
# 3       1.0
# 4       8.0
#        ...
# 995     NaN
# 996     NaN
# 997     NaN
# 998     NaN
# 999     NaN
# Name: KI-67_LI_percent, Length: 1000, dtype: float64

# %%
#KI-67_LI_percent : positively stained tumor cells , 악성 종양의 총 개수 중에서. 
shape_fig =sns.catplot(x ='KI-67_LI_percent',
            data=num_df, 
            kind='count',
           height =8,
           hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %% [markdown]
# #### 치현님 EDA 참고
# > 0 으로 채우기?

# %% [markdown]
# ### HER2_SISH_ratio

# %%
# 상관관계 찾기 
shape_fig =sns.relplot(x='ID',
                       y='HER2_SISH_ratio',
            data=train_df, 
            kind='scatter',
           height = 8 ,
           hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %% [markdown]
# 관련 있는 컬럼 찾아보고 아니면 버리기?

# %% [markdown]
# ## Categorical

# %%
cat_df = train_df[cat_cols]

cat_df.head()
# Out:
#    diag_cat  location  sng_mul   NG   HG  HG_score_1  HG_score_2  HG_score_3  \
# 0         1         2        1  2.0  1.0         2.0         2.0         1.0
# 1         1         1        1  3.0  3.0         3.0         3.0         3.0
# 2         1         2        1  2.0  NaN         NaN         NaN         NaN
# 3         1         2        1  3.0  3.0         3.0         3.0         2.0
# 4         1         2        1  2.0  2.0         3.0         2.0         1.0
#
#    DCIS_or_LCIS  DCIS_or_LCIS_type  T_category   ER   PR  HER2  HER2_IHC  \
# 0             2                NaN         1.0  1.0  1.0   0.0       1.0
# 1             0                NaN         2.0  0.0  0.0   0.0       0.0
# 2             1                2.0         0.0  1.0  1.0   0.0       1.0
# 3             1                2.0         0.0  0.0  0.0   1.0       3.0
# 4             2                NaN         1.0  1.0  0.0   1.0       2.0
#
#    HER2_SISH  BRCA_mutation  N_category
# 0        NaN            NaN           0
# 1        NaN            NaN           1
# 2        NaN            0.0           0
# 3        NaN            NaN           0
# 4        1.0            NaN           0

# %%
sns.heatmap(cat_df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Diag_cat

# %%
# 진단명

shape_fig =sns.catplot(x ='diag_cat',
            data=cat_df, 
            kind='count',
           # height =8,
            hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %% [markdown]
# ### location

# %%
# 진단명

shape_fig =sns.catplot(x ='location',
            data=cat_df, 
            kind='count',
           # height =8,
            hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %% [markdown]
# #### 전처리 항목
#
# 삭제?

# %% [markdown]
# ### 암의 개수

# %%
# 진단명

shape_fig =sns.catplot(x ='sng_mul',
            data=cat_df, 
            kind='count',
           # height =8,
            hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %%
### 핵

# %%
# 핵의 모양

shape_fig =sns.catplot(x ='NG',
            data=cat_df, 
            kind='count',
           # height =8,
            hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %% [markdown]
# #### 관찰 2
# > 핵의 모양이 정상에 가까운 경우 전이 확률 낮음

# %% [markdown]
# ### HG

# %%
# HG 가 몬데.. 

shape_fig =sns.catplot(x ='HG',
            data=cat_df, 
            kind='count',
           # height =8,
            hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %% [markdown]
# ### HG_score_1

# %%
# Tubule formation - 세관 

shape_fig =sns.catplot(x ='HG_score_1',
            data=cat_df, 
            kind='count',
           # height =8,
            hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %% [markdown]
# ### HG_score_2

# %%
# 진단명

shape_fig =sns.catplot(x ='HG_score_2',
            data=cat_df, 
            kind='count',
           # height =8,
            hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %% [markdown]
# ### HG_score_3

# %%
# 진단명

shape_fig =sns.catplot(x ='HG_score_3',
            data=cat_df, 
            kind='count',
           # height =8,
            hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %% [markdown]
# ### DCIS_or_LCIS

# %%
# 진단명

shape_fig =sns.catplot(x ='DCIS_or_LCIS',
            data=cat_df, 
            kind='count',
           # height =8,
            hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %% [markdown]
# ### DCIS_or_LCIS_type

# %%
# 진단명

shape_fig =sns.catplot(x ='DCIS_or_LCIS_type',
            data=cat_df, 
            kind='count',
           # height =8,
            hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %%
> 삭제?

# %% [markdown]
# ### T_category

# %%
# 크기별 분류? 굳이 왜 한 번 더 한지는 모르겠음 

shape_fig =sns.catplot(x ='T_category',
            data=cat_df, 
            kind='count',
           # height =8,
            hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %% [markdown]
# ### ER

# %%
# 크기별 분류? 굳이 왜 한 번 더 한지는 모르겠음 

shape_fig =sns.catplot(x ='ER',
            data=cat_df, 
            kind='count',
           # height =8,
            hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %% [markdown]
# ### PR

# %%
# 

shape_fig =sns.catplot(x ='PR',
            data=cat_df, 
            kind='count',
           # height =8,
            hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %% [markdown]
# ### HER2

# %%
# 크기별 분류? 굳이 왜 한 번 더 한지는 모르겠음 

shape_fig =sns.catplot(x ='HER2',
            data=cat_df, 
            kind='count',
           # height =8,
            hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %% [markdown]
# ### HER2_IHC

# %%
# 

shape_fig =sns.catplot(x ='HER2_IHC',
            data=cat_df, 
            kind='count',
           # height =8,
            hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %% [markdown]
# ### HER2_SISH

# %%
# 

shape_fig =sns.catplot(x ='HER2_SISH',
            data=cat_df, 
            kind='count',
           # height =8,
            hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %% [markdown]
# ### BRCA_mutation

# %%
# 

shape_fig =sns.catplot(x ='BRCA_mutation',
            data=cat_df, 
            kind='count',
           # height =8,
            hue = 'N_category'
           )

shape_fig.set_xticklabels(rotation=45)

plt.show()

# %%
'HER2_SISH','BRCA_mutation','N_category']
